# %% [markdown]
# # 3-2 연산자
#
# ## **🎯 1. 다양한 연산자의 종류 (교과서 P.131-132)**
# **학습 목표 : 다양한 연산자를 활용하여 프로그램을 작성할 수 있을까?**
#
# 파이선의 연산자는 기능에 따라 단항, 산술, 비교, 논리, 대입 연산자 등으로 분류된다.
# 한 수식에 여러 개의 연산자가 사용될 때, 연산자의 우선순위와 괄호의 결합 형태에 따라
# 연산 순서가 달라진다
#
# ![image.png](attachment:6ffdd2fe-eff7-4962-a573-1ab543a21e21.png)
#
# `산술 연산자`는 +, -, *, /과 같은 사칙 연산에 사용되고 연산 결과가 숫자로 나타난다.

# %%
# 과제1: 산술 연산자
x, y = 17, 4
print("x + y = ", x+y)
print("x - y = ", x-y)
print("x * y = ", x*y)
print("x / y = ", x/y)
print("x // y = ", x//y)
print("x % y = ", x%y)
# Out:
# x + y =  21
# x - y =  13
# x * y =  68
# x / y =  4.25
# x // y =  4
# x % y =  1

# %% [markdown]
# `비교 연산자`는 두 피연산자를 비교하여 연산 결과가 참(True), 거짓(False)의 형태로 나타난다.

# %%
# 과제2: 비교 연산자
x, y = 10, 14
print("x > y is", x>y)
print("x < y is", x<y)
print("x >= y is", x>=y)
print("x <= y is", x<=y)
print("x == y is", x==y)
print("x != y is", x!=y)
# Out:
# x > y is False
# x < y is True
# x >= y is False
# x <= y is True
# x == y is False
# x != y is True

# %% [markdown]
# `논리 연산자`는 연산 결과가 참(True), 거짓(False)의 형태로 나타난다.

# %%
# 과제3: 논리 연산자
x, y = True, False
print("x and y is", x and y)
print("x or y is", x or y)
print("not x is", not x)
# Out:
# x and y is False
# x or y is True
# not x is False

# %% [markdown]
# > 비교 연산자와 논리 연산자를 이용하여 아이디와 패스워드를 검사하여,
# True 또는 False를 출력하는 프로그램은 다음과 같다.

# %%
# 과제4: 비교 연산자와 논리 연산자 활용 - 아이디, 패스워드 검사
id = "python"
pw = "1234"
answer1 = input("아이디:")
answer2 = input("패스워드:")
print(id==answer1)
print(pw==answer2)
print(id==answer1 and pw==answer2)
# Out:
# 아이디: python
# 패스워드: 3456
# True
# False
# False

# %% [markdown]
# `대입연산자`를 사용하는 연산에서 결괏값이 저장되는 변수가 연산에 사용되는 경우, 간소화된 축약형 연산자를 사용할 수 있다.

# %%
# 과제5: 대입 연산자
x = 10
x = x + 10/2
print(x)

x = 10
x += 10/2
print(x)
# Out:
# 15.0
# 15.0

# %% [markdown]
# ## 스스로 해결하기
# <a class="jcecodle-mk jcecodle-mk__problem-chip" data-problem-id="NhMmHVzWEs8" href='#jce-judge/open/NhMmHVzWEs8' target='_self'><span>p.133 스스로 해결하기 1</span></a>
#
#
# <a class="jcecodle-mk jcecodle-mk__problem-chip" data-problem-id="r9_IKKtJZcc" href='#jce-judge/open/r9_IKKtJZcc' target='_self'><span>p.133 스스로 해결하기 2</span></a>
#
#
# <a class="jcecodle-mk jcecodle-mk__problem-chip" data-problem-id="MJxVadgjQ10" href='#jce-judge/open/MJxVadgjQ10' target='_self'><span>p.133 스스로 해결하기 3</span></a>

# %% [markdown]
# ## 스스로 점검하기
# 1. 파이선의 연산자는 기능에 따라 단항, 산술, 비교, 논리, 대입 연산자 등으로 분류한다.
# 2. 산술 연산자는 +, -, *, /와 같은 사칙 연산에 사용된다(+ 연산자는 문자열 연결 연산자로 사용하면, 문자로 출력된다).
# 3. 비교 연산자는 두 피연산자를 비교하여 연산 결과가 참(True), 거짓(False)의 형태로 나타난다.
# 4. 논리 연산자는 연산 결과가 참(True), 거짓(False)의 형태로 나타난다.
# 5. 대입 연산자를 사용하는 연산에서 결괏값이 저장되는 변수가 연산에 사용되는 경우 간소화된 축약형 연산자를 사용할 수 있다.
