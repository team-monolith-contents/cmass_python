# %% [markdown]
# # 3-4 표준입출력과 파일입출력
#
# ## **🎯 1. 프로그램 처리 과정 (교과서 P.135)**
# **학습 목표 : 프로그램 처리 과정에서 입력, 처리, 출력을 찾을 수 있을까?**
#
#  웹 사이트에 로그인할 때, 프로그램 처리 과정은 크게 3단계로 구분할 수 있다.
#  아이디와 비밀번호를 입력하는 입력 단계, 아이디와 비밀번호를 확인하는 처리 단계,
#  로그인 화면이나 알림 메시지를 보여 주는 출력 단계로 구분할 수 있다.

# %% [markdown]
# ## **🎯 2. 표준입출력 (교과서 P.135)**
# **학습 목표 : 표준입출력 프로그램은 어떻게 작성할까?**
#
# 표준 입력은 프로그램으로 입력되는 자료의 흐름(Stream)을 말하며, 대부분의 경우 키보드를
# 통해 이루어진다. 표준 출력은 프로그램에서 출력되는 자료의 흐름을 말하며, 대부분의 경우
# 모니터를 통해 이루어진다.
#
# 파이선의 표준 입력 함수는 input( ), 표준 출력 함수는 print( )이다.
#
# ![image.png](attachment:0292b65c-c456-438f-9ecb-5ef02e60f0b8.png)
#
#
# 표준입출력을 활용하면, 다음과 같이 영화 금액을 입력받고 예매 안내를 출력하는 프로그램을 작성할 수 있다.

# %%
fee = 7000
print("안녕하세요? 티켓 금액은", fee, "원입니다.")
num = input("영화를 관람하실 인원을 입력해주세요.")
total = fee*int(num)
print("예매하실 인원은", num, "명, 총 금액은", total, "원입니다.")
# Out:
# 안녕하세요? 티켓 금액은 7000 원입니다.
# 영화를 관람하실 인원을 입력해주세요. 3
# 예매하실 인원은 3 명, 총 금액은 21000 원입니다.

# %% [markdown]
# ## **🎯 3. 파일입출력**
# **학습 목표 : 파일입출력은 어떤 단계로 이루어질까?**
#
# 표준입출력을 통해 출력된 정보는 프로그램이 종료되면 저장되지 않고 사라진다.
# 또한, 많은 자료를 표준 입력을 통해 일일이 입력한다면 번거롭기도 하겠지만
# 잘못 입력할 가능성도 커진다. 이때 파일로부터 자료를 입력받고, 처리된 정보를
# 파일에 출력하는 파일입출력을 활용할 수 있다.
#
# 파일입출력은 ‘파일 열기 → 파일 처리(읽기/쓰기) → 파일 닫기’의 3단계로 이루어지
# 며
# 함수의 종류 및 사용 방법은 [표 Ⅲ-2]와 같다
#
# ![image.png](attachment:83efbdd2-5368-44b8-afe0-9ba1fbd7ad88.png)
#
# 영화 예매 프로그램에서 파일입출력 함수가 어떻게 활용되는지 알아보자.

# %%
# 과제1: 영화 예매 프로그램
f1 = open("movie.txt", "w")
title = input("영화 제목을 입력해주세요:")
fee = input("티켓 비용을 입력해주세요:")
f1.write(title+'\n')
f1.write(fee)
f1.close()
f1 = open("movie.txt", "r")
title = f1.readline()
fee = f1.readline()
print("영화 제목:", title)
print("티켓 요금:", fee)
f1.close()
# Out:
# 영화 제목을 입력해주세요: 이미테이션 게임
# 티켓 비용을 입력해주세요: 7000
# 영화 제목: 이미테이션 게임
#
# 티켓 요금: 7000

# %% [markdown]
# ## 스스로 점검하기
# 1. 파이선의 표준 출력 함수는 print(), 표준 입력 함수는 input()이다.
# 2. 파일입출력은 ‘파일 열기 → 파일 처리(읽기/쓰기) → 파일 닫기’의 3단계로 이루어진다.

# %% [markdown]
# ## 스스로 해결하기
# 파일입출력 함수를 활용하여 `과제`를 해결하는 영화 예매 프로그램을 완성해 보자.
# - 변수 설계
# ![image.png](attachment:a315270c-ac57-4a04-9ffc-ca479319a2f8.png)
#
# - 프로그래밍
#
# <a class="jcecodle-mk jcecodle-mk__problem-chip" data-problem-id="ufCmVyYB5Fs" href='#jce-judge/open/ufCmVyYB5Fs' target='_self'><span>p.137 스스로 해결하기 1</span></a>
