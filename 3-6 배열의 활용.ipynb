# %% [markdown]
# # 3-6 배열의 활용
#
# ## **🎯 1. 배열 (교과서 P.149)**
# **학습 목표 : 여러 개의 자료들을 하나의 이름으로 관리할 수 있을까?**
#
# 태양계 행성 8개의 이름을 기억 장소에 모두 저장하려면 서로 다른 이름을 가진 변수 8개가
# 필요하다. 만일 더 많은 행성 이름을 저장해야 한다면, 그만큼 더 많은 변수를 만들어야 한다.

# %%
mercury = "수성"
venus = "금성"
earth = "지구"
mars = "화성"
jupiter = "목성"
saturn = "토성"
uranus = "천왕성"
neptune = "해왕성"

print(mercury, venus, earth, mars, jupiter, saturn, uranus, neptune)
# Out:
# 수성 금성 지구 화성 목성 토성 천왕성 해왕성

# %% [markdown]
# 8개의 행성 이름을 서로 다른 이름의 변수에 각각 저장하게 되면,
# 특정 위치의 행성 이름을 자동으로 알아내야 할 때 문제 해결이
# 매우 복잡해질 수 있다.
#
# 배열을 이용하면 하나의 배열로 행성 8개의 이름을 모두 저장할 수 있기 때문에
# 문제를 효과적으로 해결할 수 있다.
#
# ![image.png](attachment:2c177e6f-3534-4a74-a36c-38a36ba6e651.png)
#
# 배열은 같은 성격의 데이터를 연속적인 공간에 저장하는 자료 구조이다.
# 배열을 하나 만들고, 8개의 행성 이름을 배열에 순서대로 저장해 두면,
# 첨자를 사용하여 특정 위치의 행성 이름을 알아낼 수 있다.

# %% [markdown]
# ## **🎯 2. 1차원 배열의 표현**
# **학습 목표 : 1차원 배열은 어떻게 작성할까?**
#
# 하나의 행 또는 열로만 구성된 배열을 1차원 배열이라고 하며, 한 가지 종류의 자료를
# 묶어서 관리하고자 할 때 주로 사용된다.
#
# 파이선은 배열을 표현하기 위해 리스트라는 특별한 구조를 사용한다.
# 리스트는 정수, 실수, 문자열 등 자료 유형이 서로 다른 자료들도
# 함께 저장할 수 있는 장점이 있다.
#
# 파이선은 대괄호([ ])를 사용하면 리스트를 생성하거나 리스트 요소에 접근할 수 있다.
# 리스트 생성 시 대괄호를 한 개만 사용하면 첨자가 한 개인 1차원 배열이 된다.
#
# 8개 행성의 이름을 1차원 배열에 저장하는 대표적인 방법은 다음과 같다.
#
# - 초깃값을 부여하는 방법
# ![image.png](attachment:dd054a06-7188-48b8-8070-7df7415a869b.png)
#
# - 배열의 크기를 지정하는 방법
# ![image.png](attachment:3594e329-8ab3-4a76-8ada-fcf8f68fffa6.png)
#
# 위의 방법에 따라 planet이라는 배열을 만들면 다음과 같이 저장된다.
# ![image.png](attachment:80f3cbc3-b176-48a6-b190-315acc298f7f.png)
#
# for문을 한 번만 사용하면 1차원 배열의 모든 요소를 출력할 수 있다.
# ![image.png](attachment:f56f3b9e-a5f0-4a2e-8a31-230a4973fb49.png)
#
#
# 1차원 배열의 특정 요소에 접근할 때에는 대괄호([ ]) 한 개와 첨자 한 개를 사용하여
# 다음과 같이 표현한다.
# ![image.png](attachment:b5002438-2206-4487-a731-b8f5bfc35abf.png)

# %% [markdown]
# ## 스스로 해결하기
# <a class="jcecodle-mk jcecodle-mk__problem-chip" data-problem-id="oc7Pu8HCQXk" href='#jce-judge/open/oc7Pu8HCQXk' target='_self'><span>p.151 스스로 해결하기 1</span></a>
#
# <a class="jcecodle-mk jcecodle-mk__problem-chip" data-problem-id="3GPnZlywWL0" href='#jce-judge/open/3GPnZlywWL0' target='_self'><span>p.151 스스로 해결하기 1 - 응용하기</span></a>

# %% [markdown]
# ## **🎯 3. 2차원 배열의 표현**
# **학습 목표 : 2차원 배열은 어떻게 작성할까?**
# 태양계 행성들의 이름만 저장하는 것이라면 1차원 배열로도 충분하다.
# 그러나 행성의 이름뿐만 아니라 행성의 크기, 질량 등도 함께 저장해야 한다면
# 2차원 배열을 사용하는 것이 효과적이다.
# 2차원 배열은 여러 과목 점수표와 같이 여러 개의 행과 열로 구성된다.
# 배열 생성 시 대괄호([ ]) 두 개를 사용하면 첨자가 두 개인 2차원 배열을 만들 수 있다.
#
# 2차원 배열을 만드는 대표적인 방법은 다음과 같다.
#
# - 초깃값을 부여하는 방법
# ![image.png](attachment:a4954e96-0dba-4159-8eb0-0d437c0522c4.png)
#
# - 반복문을 이용하는 방법
# ![image.png](attachment:f7cd547f-09bf-465f-90d4-24ff7f8eb176.png)
#
# 8개 행성의 이름, 크기, 질량을 2차원 배열 planet에 저장하면 다음과 같다.
# ![image.png](attachment:d0942d6d-bfe9-405a-9fbc-9220a0c380b6.png)
#
# for문을 중첩하면 2차원 배열의 모든 요소를 출력할 수 있다.
# ![image.png](attachment:c511b47b-3197-4239-b970-f27eac7b785d.png)
#
# 2차원 배열의 특정 요소에 접근할 때에는 대괄호([ ]) 두 개와 첨자 두 개를 사용하여 다음과 같이 표현한다.
#
# ![image.png](attachment:a718a4f5-4f81-457d-b6c0-6c309faff9bf.png)

# %% [markdown]
# ## 스스로 해결하기
# <a class="jcecodle-mk jcecodle-mk__problem-chip" data-problem-id="bSu9_GXcYf8" href='#jce-judge/open/bSu9_GXcYf8' target='_self'><span>p.153 스스로 해결하기 2</span></a>

# %% [markdown]
# ### **💯 더 알아보기**
#
# 1. **리스트 내포**
#
# 리스트 내포는 대괄호([ ]) 안에 for, in, if 키워드를 사용하여 리스트를 생성하는 구문으로,
# 리스트 내장 또는 지능형 리스트라고도 한다. 이 방법을 사용하면 특정한 규칙을 가진 리스트를
# 매우 쉽고 간결하게 만들 수 있다.
# > ![image.png](attachment:0f69c529-a031-49c9-ac15-6f9f575ca936.png)
# > -  시퀀스(범위, 리스트, 문자열 등)에 들어 있는 값들을 하나씩 변수에 넣고 조건식을 판정하여
# 판정 결과가 참일 때에만 변수를 표현식에 적용해서 그 결과를 리스트의 요소 값으로 추가한다.
# >-  if 조건식은 생략 가능하다.
#
# `리스트 내포 사용 예문`
# ![image.png](attachment:28dd05eb-72bf-482f-91bb-6e4a56cde4ec.png)
#
# <br>
#
# 2. **리스트 내장 메소드**
#
# 자주 사용하는 리스트 내장 메소드를 정리하면 다음과 같다.
#
# ![image.png](attachment:2c0f0912-744e-4aed-891f-9a1e06184aa6.png)

# %% [markdown]
# ## 스스로 해결하기
# <a class="jcecodle-mk jcecodle-mk__problem-chip" data-problem-id="zALOOhkU_fg" href='#jce-judge/open/zALOOhkU_fg' target='_self'><span>p.155 스스로 해결하기 3-1</span></a>
#
# <a class="jcecodle-mk jcecodle-mk__problem-chip" data-problem-id="xBGKce4yfGY" href='#jce-judge/open/xBGKce4yfGY' target='_self'><span>p.155 스스로 해결하기 3-2</span></a>

# %% [markdown]
# ## **🎯 4. 배열의 활용**
# **학습 목표 : 배열을 활용하여 프로그램을 작성할 수 있을까?**
# ‘미키마우스.txt’ 파일에는 0과 1로만 이루어진 자료가 들어 있다.
# 이 파일을 읽어서 터틀 캔버스 상에 0은 흰 점, 1은 검은 점으로
# 표현하여 미키마우스 이미지를 출력하는 프로그램을 작성해 보자.
#
# ![image.png](attachment:95c09b69-5d83-456e-bcc3-a62fe8252f6d.png)

# %%
#하단 코드를 실행시켜 주세요.
# !pip3 install ColabTurtlePlus

# %%
#하단 코드를 실행시켜 주세요.
f=open("미키마우스.txt", 'w')
f.write('''000011111000000\n000111111100000\n000111111101110\n000111111101111\n000011111011111\n000001111111111
000010100111111\n000100000011110\n000101010011100\n110101010011100\n111110000110100\n110000000000100\n010000000101100\n001100001011000\n000011111110000''')
# Out:
# Put clearscreen() as the first line in a cell (after the import command) to re-run turtle commands in the cell
# 239

# %%
from ColabTurtlePlus.Turtle import *
oldDefaults()

#from turtle import *
f=open("미키마우스.txt")
s=[ ]
for row in f.readlines( ):
    s.append(list(row.strip( )))
penup( )
setup(width = 700, height = 700)
for y in range(15):
    for x in range(15):
        goto(x*20+350,y*20+350)
        if s[y][x]=="1":
            color("black")
        else:
            color("white")
        dot(20)
# Out:
# Put clearscreen() as the first line in a cell (after the import command) to re-run turtle commands in the cell
#       <svg width="700" height="700">
#         <rect width="100%" height="100%" style="fill:black;stroke:;stroke-width:1"/>
#
#
#
# ...

# %% [markdown]
# ## 스스로 점검하기
# 1. 배열은같은성격의자료들을연속적인공간에저장하는자료구조이다.
# 2. 파이선은 배열을 표현하기 위해 리스트라는 특별한 구조를 사용한다.
# 리스트는 정수, 실수, 문자열 등 데이터 유형이 서로 다른 자료들도 함께 저장할 수 있다.

# %% [markdown]
# ## 함께 해결하기
# <a class="jcecodle-mk jcecodle-mk__problem-chip" data-problem-id="vfz9FUjfKOc" href='#jce-judge/open/vfz9FUjfKOc' target='_self'><span>p.157 함께 해결하기</span></a>
